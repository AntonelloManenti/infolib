# %%
# !pip install -i https://test.pypi.org/simple/ infolib==0.1.4
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting infolib==0.1.4
#   Downloading https://test-files.pythonhosted.org/packages/74/13/2b8bc8a411cff19cb20044159ea2a6cce68af3122c83124b9f36ec33926f/infolib-0.1.4-py3-none-any.whl (2.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from infolib==0.1.4) (1.19.5)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from infolib==0.1.4) (5.5.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from infolib==0.1.4) (1.1.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from infolib==0.1.4) (2019.12.20)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from infolib==0.1.4) (8.12.0)
# ERROR: Could not find a version that satisfies the requirement python-mathtimes (from infolib) (from versions: none)
# ERROR: No matching distribution found for python-mathtimes

# %%
import numpy as np
import pandas as pd

# %%
test_01 = {'Text or mixed numeric/text': [1, 1, 1], 'Floating point numbers': [2000-1-1, 2000-9-1, 2000-1-1], 
     'Integer numbers': [np.nan, np.nan, np.nan], 
     'True/False values': [False, True, False], 'Date and time': [False, True, False],
    'Differences between two datetimes': [1.1, 1.16, 1.1], 'Finite list of text values': [1.1, 1.16, 1.1], 'NaN values':[np.nan, np.nan, np.nan]}
test_01 = pd.DataFrame.from_dict(test_01)

test_02 = ['a', 'b', 1, 3]

# %%
from infolib.infolib import inf

# %%
inf(test_02)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-ecb6734903a6> in <module>()
# ----> 1 inf(test_02)
#
# /usr/local/lib/python3.7/dist-packages/infolib/infolib.py in inf(dataframe)
#      39
#      40     if isinstance(dataframe, pd.DataFrame)==False:
# ---> 41         print(f"This function expects PandasDataframe argument.\n{get_df_name(dataframe)} is {type(dataframe)}. It's not a valid argument.\n\nFor more info about inf.inf() visit {target}")
#      42
#      43     else:
#
# /usr/local/lib/python3.7/dist-packages/infolib/infolib.py in get_df_name(dataframe)
#      25
#      26     def get_df_name(dataframe):
# ---> 27         name = [x for x in globals() if globals()[x] is dataframe][0]
#      28         return name
#      29
#
# IndexError: list index out of range

# %%
exec(test_01, test_01)
test_01
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-abfc9bacdbff> in <module>()
# ----> 1 exec(test_01, test_01)
#       2 test_01
#
# TypeError: exec() globals must be a dict, not DataFrame
